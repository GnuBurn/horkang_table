# %%
from ultralytics import YOLO
import cv2
import config
import matplotlib.pyplot as plt
import os

# %%
print(config.HUMAN_MODEL_NAME)
model = YOLO(config.HUMAN_MODEL_NAME)
print(f"Model loaded")
# Out:
# runs\detect\human_detector_v2\weights\best.pt
# Model loaded

# %%
folder_path = 'sample_data/test_img'

images = [f for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

for img_name in images:
    full_path = os.path.join(folder_path, img_name)
    results = model(full_path)
    for r in results:
        count = len(r.boxes)
        print(f"File: {img_name} | Humans detected: {count}")
        
        # Optional: Show the first 3 images to verify
        # (Using a counter here avoids flooding your notebook if you have 1000 images)
        annotated_img = r.plot()
        rgb_img = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
        plt.imshow(rgb_img)
        plt.title(f"Detected: {count}")
        plt.axis('off')
        plt.show()
# Out:
# image 1/1 e:\Projects\CCTV_horkang\sample_data\test_img\test_12_1.png: 384x640 3 humans, 31.8ms
# Speed: 1.6ms preprocess, 31.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# File: test_12_1.png | Humans detected: 3
# image 1/1 e:\Projects\CCTV_horkang\sample_data\test_img\test_3_1.jpg: 384x640 2 humans, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# File: test_3_1.jpg | Humans detected: 2
# image 1/1 e:\Projects\CCTV_horkang\sample_data\test_img\test_4_1.png: 384x640 5 humans, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# File: test_4_1.png | Humans detected: 5
# image 1/1 e:\Projects\CCTV_horkang\sample_data\test_img\test_9_1.png: 384x640 5 humans, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# File: test_9_1.png | Humans detected: 5
